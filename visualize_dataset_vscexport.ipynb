# %%
import pandas as pd

df = pd.read_excel("Online Retail.xlsx")

# %%
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 5 2010-12-01 08:26:00       7.65     17850.0  United Kingdom
# 6 2010-12-01 08:26:00       4.25     17850.0  United Kingdom
# 7 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 8 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 9 2010-12-01 08:34:00       1.69     13047.0  United Kingdom

# %%
df.describe(include='all')
# Out:
#         InvoiceNo StockCode                         Description  \
# count    541909.0    541909                              540455
# unique    25900.0      4070                                4223
# top      573585.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq       1114.0      2313                                2369
# mean          NaN       NaN                                 NaN
# min           NaN       NaN                                 NaN
# 25%           NaN       NaN                                 NaN
# 50%           NaN       NaN                                 NaN
# 75%           NaN       NaN                                 NaN
# max           NaN       NaN                                 NaN
# std           NaN       NaN                                 NaN
#
#              Quantity                    InvoiceDate      UnitPrice  \
# count   541909.000000                         541909  541909.000000
# unique            NaN                            NaN            NaN
# top               NaN                            NaN            NaN
# freq              NaN                            NaN            NaN
# mean         9.552250  2011-07-04 13:34:57.156386048       4.611114
# min     -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%          1.000000            2011-03-28 11:34:00       1.250000
# 50%          3.000000            2011-07-19 17:17:00       2.080000
# 75%         10.000000            2011-10-19 11:27:00       4.130000
# max      80995.000000            2011-12-09 12:50:00   38970.000000
# std        218.081158                            NaN      96.759853
#
#            CustomerID         Country
# count   406829.000000          541909
# unique            NaN              38
# top               NaN  United Kingdom
# freq              NaN          495478
# mean     15287.690570             NaN
# min      12346.000000             NaN
# 25%      13953.000000             NaN
# 50%      15152.000000             NaN
# 75%      16791.000000             NaN
# max      18287.000000             NaN
# std       1713.600303             NaN

# %%
df.dropna(inplace=True)
df.describe(include='all')
# Out:
#         InvoiceNo StockCode                         Description  \
# count    406829.0    406829                              406829
# unique    22190.0      3684                                3896
# top      576339.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq        542.0      2077                                2070
# mean          NaN       NaN                                 NaN
# min           NaN       NaN                                 NaN
# 25%           NaN       NaN                                 NaN
# 50%           NaN       NaN                                 NaN
# 75%           NaN       NaN                                 NaN
# max           NaN       NaN                                 NaN
# std           NaN       NaN                                 NaN
#
#              Quantity                    InvoiceDate      UnitPrice  \
# count   406829.000000                         406829  406829.000000
# unique            NaN                            NaN            NaN
# top               NaN                            NaN            NaN
# freq              NaN                            NaN            NaN
# mean        12.061303  2011-07-10 16:30:57.879207424       3.460471
# min     -80995.000000            2010-12-01 08:26:00       0.000000
# 25%          2.000000            2011-04-06 15:02:00       1.250000
# 50%          5.000000            2011-07-31 11:48:00       1.950000
# 75%         12.000000            2011-10-20 13:06:00       3.750000
# max      80995.000000            2011-12-09 12:50:00   38970.000000
# std        248.693370                            NaN      69.315162
#
#            CustomerID         Country
# count   406829.000000          406829
# unique            NaN              37
# top               NaN  United Kingdom
# freq              NaN          361878
# mean     15287.690570             NaN
# min      12346.000000             NaN
# 25%      13953.000000             NaN
# 50%      15152.000000             NaN
# 75%      16791.000000             NaN
# max      18287.000000             NaN
# std       1713.600303             NaN

# %%
df = df[df['Quantity'] > 0]

# %%
df = df[df['UnitPrice'] > 0]

# %%
df = df[df['StockCode'].apply(lambda x: len(str(x)) == 5)]

# %%
df['Description'] = df['Description'].str.strip()

# %%
print(df.describe(include='all'))
print('Number of rows:', len(df))
# Out:
#         InvoiceNo  StockCode               Description       Quantity  \
# count    363087.0   363087.0                    363087  363087.000000
# unique    18220.0     2785.0                      2976            NaN
# top      576339.0    22423.0  REGENCY CAKESTAND 3 TIER            NaN
# freq        485.0     1723.0                      1723            NaN
# mean          NaN        NaN                       NaN      13.092044
# min           NaN        NaN                       NaN       1.000000
# 25%           NaN        NaN                       NaN       2.000000
# 50%           NaN        NaN                       NaN       6.000000
# 75%           NaN        NaN                       NaN      12.000000
# max           NaN        NaN                       NaN   80995.000000
# std           NaN        NaN                       NaN     187.385204
#
#                           InvoiceDate      UnitPrice     CustomerID  \
# count                          363087  363087.000000  363087.000000
# unique                            NaN            NaN            NaN
# top                               NaN            NaN            NaN
# freq                              NaN            NaN            NaN
# mean    2011-07-12 18:01:57.008651008       2.886352   15295.839394
# min               2010-12-01 08:26:00       0.040000   12346.000000
# 25%               2011-04-10 11:33:00       1.250000   13969.000000
# 50%               2011-08-03 10:49:00       1.740000   15159.000000
# 75%               2011-10-21 14:49:00       3.750000   16794.000000
# max               2011-12-09 12:50:00     649.500000   18287.000000
# std                               NaN       4.362079    1711.926569
#
#                Country
# count           363087
# unique              37
# top     United Kingdom
# freq            323566
# mean               NaN
# min                NaN
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max                NaN
# std                NaN
# Number of rows: 363087

# %%
import matplotlib.pyplot as plt
import seaborn as sns

top5_selling_countries = df["Country"].value_counts()[:5]
sns.barplot(x=top5_selling_countries.index, y=top5_selling_countries.values)
plt.xlabel("Country")
plt.ylabel("Amount")
plt.title("Top 5 Selling Countries")
# Out:
# Text(0.5, 1.0, 'Top 5 Selling Countries')

# %%
top20_selling_products = df['Description'].value_counts()[:20]
plt.figure(figsize=(10,6))
sns.barplot(y=top20_selling_products.index, x=top20_selling_products.values, orient='h')
plt.xlabel("Amount")
plt.ylabel("Product")
plt.title("Top 20 Selling Products")
plt.tight_layout()

# %%
df_uk = df[df['Country'] == 'United Kingdom']

# %%
from datetime import datetime
df_uk["YearMonth"] = df["InvoiceDate"].apply(lambda dt: datetime(year=dt.year, month=dt.month, day=1))
df_uk['Revenue'] = df_uk['Quantity'] * df_uk['UnitPrice']
revenue_by_month = df_uk.groupby('YearMonth')['Revenue'].sum()
print(revenue_by_month)


revenue_by_month = df_uk.groupby("YearMonth")["Revenue"].sum()
plt.figure(figsize=(12, 6))
sns.lineplot(x=revenue_by_month.index, y=revenue_by_month.values)
plt.xlabel("Year-Month")
plt.ylabel("Gross Revenue")
plt.title("Gross Revenue by Month and Year")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-13-bb4d36a666a5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_uk["YearMonth"] = df["InvoiceDate"].apply(lambda dt: datetime(year=dt.year, month=dt.month, day=1))
# <ipython-input-13-bb4d36a666a5>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_uk['Revenue'] = df_uk['Quantity'] * df_uk['UnitPrice']
# YearMonth
# 2010-12-01    442351.04
# 2011-01-01    386773.68
# 2011-02-01    315535.50
# 2011-03-01    413809.39
# 2011-04-01    361118.06
# 2011-05-01    489549.13
# 2011-06-01    480681.56
# 2011-07-01    431988.07
# 2011-08-01    447232.92
# 2011-09-01    738685.16
# 2011-10-01    759879.72
# 2011-11-01    901765.44
# 2011-12-01    453998.76
# Name: Revenue, dtype: float64

# %%
# we are only interested in InvoiceNo, StockCode, Description columns
df_uk[['InvoiceNo', 'StockCode', 'Description']].to_pickle('UK.pkl')

# %%
df = pd.read_pickle('UK.pkl')
print(df)
# Out:
#        InvoiceNo StockCode                          Description
# 1         536365     71053                  WHITE METAL LANTERN
# 5         536365     22752         SET 7 BABUSHKA NESTING BOXES
# 6         536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER
# 7         536366     22633               HAND WARMER UNION JACK
# 8         536366     22632            HAND WARMER RED POLKA DOT
# ...          ...       ...                                  ...
# 541889    581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY
# 541891    581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK
# 541892    581586     21217        RED RETROSPOT ROUND CAKE TINS
# 541893    581586     20685                DOORMAT RED RETROSPOT
#
# [323566 rows x 3 columns]
